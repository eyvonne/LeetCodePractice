# %% [markdown]
# A Time series of dayly reading levels is provided.
# Some of the data is missing.
#
# Find the missing data

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
input0 = []
with open('input000.txt', 'r') as data:
    for line in data:
        input0.append(line.split())
input0[1:]
# Out:
# [['1/3/2012', '16:00:00', '26.96'],
#  ['1/4/2012', '16:00:00', '27.47'],
#  ['1/5/2012', '16:00:00', '27.728'],
#  ['1/6/2012', '16:00:00', '28.19'],
#  ['1/9/2012', '16:00:00', '28.1'],
#  ['1/10/2012', '16:00:00', '28.15'],
#  ['1/11/2012', '16:00:00', '27.98'],
#  ['1/12/2012', '16:00:00', '28.02'],
#  ['1/13/2012', '16:00:00', '28.25'],
#  ['1/17/2012', '16:00:00', '28.65'],
#  ['1/18/2012', '16:00:00', '28.4'],
#  ['1/19/2012', '16:00:00', '28.435'],
#  ['1/20/2012', '16:00:00', '29.74'],
#  ['1/23/2012', '16:00:00', '29.95'],
#  ['1/24/2012', '16:00:00', '29.5703'],
#  ['1/25/2012', '16:00:00', '29.65'],
#  ['1/26/2012', '16:00:00', '29.7'],
#  ['1/27/2012', '16:00:00', '29.53'],
#  ['1/30/2012', '16:00:00', '29.62'],
#  ['1/31/2012', '16:00:00', '29.7'],
#  ['2/1/2012', '16:00:00', '30.05'],
#  ['2/2/2012', '16:00:00', '30.17'],
#  ['2/3/2012', '16:00:00', '30.4'],
#  ['2/6/2012', '16:00:00', '30.22'],
#  ['2/7/2012', '16:00:00', '30.485'],
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
pd.DataFrame(input[1:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d22f8216d90a> in <module>
# ----> 1 pd.DataFrame(input[1:])
#
# TypeError: 'method' object is not subscriptable

# %%
train = []
find = []
for line in input0[1:]:
    try:
        train.append([line[0], float(line[2])])
    except:
        find.append([line[0], line[2]])
train = pd.DataFrame(np.array(train))
find = pd.DataFrame(np.array(find))

# %%
find
# Out:
#              0           1
# 0    3/13/2012   Missing_1
# 1    3/21/2012   Missing_2
# 2    3/26/2012   Missing_3
# 3    5/24/2012   Missing_4
# 4     6/1/2012   Missing_5
# 5     6/4/2012   Missing_6
# 6    7/20/2012   Missing_7
# 7    7/23/2012   Missing_8
# 8    7/26/2012   Missing_9
# 9    9/10/2012  Missing_10
# 10   9/17/2012  Missing_11
# 11   9/20/2012  Missing_12
# 12   10/9/2012  Missing_13
# 13  10/10/2012  Missing_14
# 14  10/15/2012  Missing_15
# 15  10/31/2012  Missing_16
# 16   11/6/2012  Missing_17
# 17  11/13/2012  Missing_18
# 18  11/16/2012  Missing_19
# 19  12/13/2012  Missing_20

# %%
(pd.to_datetime(train[0]).iloc[1] - pd.to_datetime(train[0]).iloc[0]).dt.days
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-cf1276a080b8> in <module>
# ----> 1 (pd.to_datetime(train[0]).iloc[1] - pd.to_datetime(train[0]).iloc[0]).dt.days
#
# AttributeError: 'Timedelta' object has no attribute 'dt'

# %%
test
# Out:
# []

# %%
train[0] = pd.to_datetime(train[0]).astype(int)
find[0] = pd.to_datetime(find[0]).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(train[[0]], train[1])

# %%
model = RandomForestRegressor(n_jobs = -1)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# /Users/eyvonnegeordan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.934617532440974

# %%
list(model.predict(find[[0]]))
# Out:
# [32.87599999999999,
#  32.23,
#  32.14200000000001,
#  29.387999999999995,
#  29.481800000000003,
#  29.641999999999996,
#  30.636000000000003,
#  29.491999999999997,
#  29.628000000000004,
#  30.958,
#  31.25,
#  31.556000000000004,
#  29.45,
#  29.45,
#  29.719000000000005,
#  29.335500000000003,
#  29.7075,
#  27.226,
#  27.034,
#  27.206]

# %%
train = []
find = []
for line in input0[1:]:
    try:
        train.append([line[0], float(line[2])])
    except:
        find.append([line[0], line[2]])
train = pd.DataFrame(np.array(train))
find = pd.DataFrame(np.array(find))
train[0] = pd.to_datetime(train[0], infer_datetime_format=True).astype(int)
find[0] = pd.to_datetime(find[0], infer_datetime_format=True).astype(int)
model = RandomForestRegressor(n_jobs = -1)
model.fit(train[[0]], train[1])
list(model.predict(find[[0]]))
# Out:
# /Users/eyvonnegeordan/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [32.547,
#  32.266,
#  32.699999999999996,
#  29.439999999999998,
#  29.431800000000003,
#  29.006999999999998,
#  30.459000000000003,
#  29.509000000000004,
#  29.586999999999996,
#  31.061,
#  31.212,
#  31.425000000000004,
#  29.692,
#  29.424,
#  29.668,
#  29.397000000000002,
#  29.698999999999995,
#  28.633999999999997,
#  27.220999999999997,
#  27.251000000000005]
